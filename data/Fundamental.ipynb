# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
# Import the fundamental dataset All Values are growth values
fundamental = pd.read_csv('ProjectOmega.csv')
fundamental.head()
# Out:
#   Symbol                     Name    SEDOL FDS Ticker Symbol  \
# 0    MMM               3M Company  2595708            MMM-US
# 1    AOS  A. O. Smith Corporation  2816023            AOS-US
# 2    ABT      Abbott Laboratories  2002305            ABT-US
# 3   ABMD            ABIOMED, Inc.  2003698           ABMD-US
# 4    ACN    Accenture Plc Class A  B4BNMY3            ACN-US
#
#          GICS Sector Name  Net Sales  Net Sales.1  Net Sales.2  Net Sales.3  \
# 0             Industrials      -0.02         0.04         0.05        -0.01
# 1             Industrials      -0.06         0.06         0.12         0.06
# 2             Health Care       0.04         0.12         0.31         0.02
# 3             Health Care       0.30         0.33         0.35         0.43
# 4  Information Technology       0.05         0.11         0.06         0.06
#
#    Net Sales.4  ...  Market Value  Market Value.1  Market Value.2  \
# 0        -0.05  ...         -0.08           -0.22            0.31
# ...

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,25],fundamental.iloc[:,5])
plt.xlabel('Market Value Growth 2019')
plt.ylabel('Net Sales Growth 2019')
Market_Value = fundamental.iloc[:,25]
Net_Sales = fundamental.iloc[:,5]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.25

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,26],fundamental.iloc[:,6])
plt.xlabel('Market Value Growth 2018')
plt.ylabel('Net Sales Growth 2018')
Market_Value = fundamental.iloc[:,26]
Net_Sales = fundamental.iloc[:,6]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.36

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,27],fundamental.iloc[:,7])
plt.xlabel('Market Value Growth 2017')
plt.ylabel('Net Sales Growth 2017')
Market_Value = fundamental.iloc[:,27]
Net_Sales = fundamental.iloc[:,7]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.34

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,28],fundamental.iloc[:,8])
plt.xlabel('Market Value Growth 2016')
plt.ylabel('Net Sales Growth 2016')
Market_Value = fundamental.iloc[:,28]
Net_Sales = fundamental.iloc[:,8]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.28

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,29],fundamental.iloc[:,9])
plt.xlabel('Market Value Growth 2015')
plt.ylabel('Net Sales Growth 2015')
Market_Value = fundamental.iloc[:,29]
Net_Sales = fundamental.iloc[:,9]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.36

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,30],fundamental.iloc[:,10])
plt.xlabel('Market Value Growth 2014')
plt.ylabel('Net Sales Growth 2014')
Market_Value = fundamental.iloc[:,30]
Net_Sales = fundamental.iloc[:,10]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.34

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,31],fundamental.iloc[:,11])
plt.xlabel('Market Value Growth 2013')
plt.ylabel('Net Sales Growth 2013')
Market_Value = fundamental.iloc[:,31]
Net_Sales = fundamental.iloc[:,11]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.61

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,32],fundamental.iloc[:,12])
plt.xlabel('Market Value Growth 2012')
plt.ylabel('Net Sales Growth 2012')
Market_Value = fundamental.iloc[:,32]
Net_Sales = fundamental.iloc[:,12]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.44

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,33],fundamental.iloc[:,13])
plt.xlabel('Market Value Growth 2011')
plt.ylabel('Net Sales Growth 2011')
Market_Value = fundamental.iloc[:,33]
Net_Sales = fundamental.iloc[:,13]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.09

# %%
# For the first example, determine which pairs of factors are correlated. 
plt.scatter(fundamental.iloc[:,34],fundamental.iloc[:,14])
plt.xlabel('Market Value Growth 2010')
plt.ylabel('Net Sales Growth 2010')
Market_Value = fundamental.iloc[:,34]
Net_Sales = fundamental.iloc[:,14]
correlation = st.pearsonr(Market_Value,Net_Sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.07

# %%
fundamental_df = pd.read_csv('ProjectOmega.csv')
sales2019 = fundamental_df['Net Sales']
sales2019.head(10)
# Out:
# 0   -0.02
# 1   -0.06
# 2    0.04
# 3    0.30
# 4    0.05
# 5   -0.14
# 6    0.24
# 7    0.01
# 8    0.04
# 9   -0.05
# Name: Net Sales, dtype: float64

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
quartiles = sales2019.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of sales growth is: {lowerq}")
print(f"The upper quartile of sales growth is: {upperq}")
print(f"The interquartile range of sales growth is: {iqr}")
print(f"The median of sales growth is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of sales growth is: -0.01
# The upper quartile of sales growth is: 0.08
# The interquartile range of sales growth is: 0.09
# The median of sales growth is: 0.03
# Values below -0.14500000000000002 could be outliers.
# Values above 0.21500000000000002 could be outliers.

# %%
sales2018 = fundamental_df['Net Sales.1']
sales2018.head(10)
# Out:
# 0    0.04
# 1    0.06
# 2    0.12
# 3    0.33
# 4    0.11
# 5    0.07
# 6    0.24
# 7    0.02
# 8    0.23
# 9    0.02
# Name: Net Sales.1, dtype: float64

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
quartiles = sales2018.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of sales growth is: {lowerq}")
print(f"The upper quartile of sales growth is: {upperq}")
print(f"The interquartile range of sales growth is: {iqr}")
print(f"The median of sales growth is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of sales growth is: 0.03
# The upper quartile of sales growth is: 0.14
# The interquartile range of sales growth is: 0.11000000000000001
# The median of sales growth is: 0.08
# Values below -0.13500000000000004 could be outliers.
# Values above 0.30500000000000005 could be outliers.

# %%
# Filter the DataFrame down only to those columns to chart
symbol_and_sales2019 = fundamental_df[["Symbol","Net Sales"]]

# Set the index to be "State" so they will be used as labels
symbol_and_sales2019 = symbol_and_sales2019.set_index("Symbol")

symbol_and_sales2019.head()
# Out:
#         Net Sales
# Symbol
# MMM         -0.02
# AOS         -0.06
# ABT          0.04
# ABMD         0.30
# ACN          0.05

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
symbol_and_sales2019.plot(kind="bar", figsize=(20,5))

# Set a title for the chart
plt.title("Sales Growth per Company")

plt.show()
plt.tight_layout()

# %%
average_unemployment.plot(label="World Average")
combined_unemployed_data.loc['USA', "2010":"2014"].plot(label="United States")
plt.legend()
plt.show()
